# %%
from pykrx import stock
from elasticsearch import Elasticsearch
from konlpy.tag import Mecab

es = Elasticsearch()

# %% [markdown]
# # Data

# %%
mecab = Mecab()

# %%
ticker_ids = stock.get_market_ticker_list("20190225")

tickers = list()
for tk in ticker_ids:
    name = stock.get_market_ticker_name(tk)
    item = {
        'name': name, 
        'ticker': tk, 
        'suggest': {
            'input': mecab.morphs(name), 
            'weight': 1
        }
    }
    tickers.append(item)
    
print('size:', len(tickers))
tickers[:5]
# Out:
# size: 788
# [{'name': 'AJ네트웍스',
#   'ticker': '095570',
#   'suggest': {'input': ['AJ', '네트', '웍스'], 'weight': 1}},
#  {'name': 'SK렌터카',
#   'ticker': '068400',
#   'suggest': {'input': ['SK', '렌터카'], 'weight': 1}},
#  {'name': 'AK홀딩스',
#   'ticker': '006840',
#   'suggest': {'input': ['AK', '홀딩스'], 'weight': 1}},
#  {'name': 'BGF',
#   'ticker': '027410',
#   'suggest': {'input': ['BGF'], 'weight': 1}},
#  {'name': 'BGF리테일',
#   'ticker': '282330',
#   'suggest': {'input': ['BGF', '리', '테일'], 'weight': 1}}]

# %% [markdown]
# # Insert
#
#  - Index: Database
#  - Datatype: Document Type
#  - Id: Document ID

# %%
# Delete ticker index
es.indices.delete(index='tickers', ignore=[400, 404])

# Mapping
mappings = {
    'mappings': {
        'properties': {
            'name': {'type': 'text'}, 
            'ticker': {'type': 'text'}, 
            'suggest': {'type': 'completion'}
        }
    }
}
es.indices.create('tickers', body=mappings)


# Insert tickers
[es.index(index='tickers', body=tk) for tk in tickers]
# Out:
# [{'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'p17LRnYByPpEVaaD3rcv',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 0,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'qF7LRnYByPpEVaaD3rdE',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 1,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'qV7LRnYByPpEVaaD3rdS',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 2,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'ql7LRnYByPpEVaaD3rdf',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 3,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'q17LRnYByPpEVaaD3rdt',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 4,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'rF7LRnYByPpEVaaD3reA',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 5,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'rV7LRnYByPpEVaaD3reO',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 6,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'rl7LRnYByPpEVaaD3reb',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 7,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'r17LRnYByPpEVaaD3rep',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 8,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'sF7LRnYByPpEVaaD3re2',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 9,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'sV7LRnYByPpEVaaD3rfE',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 10,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'sl7LRnYByPpEVaaD3rfR',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 11,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 's17LRnYByPpEVaaD3rff',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 12,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'tF7LRnYByPpEVaaD3rfs',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 13,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'tV7LRnYByPpEVaaD3rf5',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 14,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'tl7LRnYByPpEVaaD37cH',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 15,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 't17LRnYByPpEVaaD37cU',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 16,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'uF7LRnYByPpEVaaD37ch',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 17,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'uV7LRnYByPpEVaaD37cv',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 18,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'ul7LRnYByPpEVaaD37c8',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 19,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'u17LRnYByPpEVaaD37dJ',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 20,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'vF7LRnYByPpEVaaD37dV',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 21,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'vV7LRnYByPpEVaaD37di',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 22,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'vl7LRnYByPpEVaaD37d0',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 23,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'v17LRnYByPpEVaaD37eB',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 24,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'wF7LRnYByPpEVaaD37eN',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 25,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'wV7LRnYByPpEVaaD37ea',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 26,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'wl7LRnYByPpEVaaD37en',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 27,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'w17LRnYByPpEVaaD37ez',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 28,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'xF7LRnYByPpEVaaD37e_',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 29,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'xV7LRnYByPpEVaaD37fL',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 30,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'xl7LRnYByPpEVaaD37fX',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 31,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'x17LRnYByPpEVaaD37fj',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 32,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'yF7LRnYByPpEVaaD37fv',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 33,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'yV7LRnYByPpEVaaD37f8',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 34,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'yl7LRnYByPpEVaaD4LcI',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 35,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'y17LRnYByPpEVaaD4LcU',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 36,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'zF7LRnYByPpEVaaD4Lcg',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 37,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'zV7LRnYByPpEVaaD4Lcs',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 38,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'zl7LRnYByPpEVaaD4Lc5',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 39,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'z17LRnYByPpEVaaD4LdL',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 40,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '0F7LRnYByPpEVaaD4LdX',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 41,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '0V7LRnYByPpEVaaD4Ldk',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 42,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '0l7LRnYByPpEVaaD4Ldx',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 43,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '017LRnYByPpEVaaD4Ld9',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 44,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '1F7LRnYByPpEVaaD4LeK',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 45,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '1V7LRnYByPpEVaaD4Lec',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 46,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '1l7LRnYByPpEVaaD4Leq',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 47,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '117LRnYByPpEVaaD4Le8',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 48,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '2F7LRnYByPpEVaaD4LfQ',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 49,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '2V7LRnYByPpEVaaD4Lfe',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 50,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '2l7LRnYByPpEVaaD4Lfr',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 51,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '217LRnYByPpEVaaD4Lf6',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 52,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '3F7LRnYByPpEVaaD4bcG',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 53,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '3V7LRnYByPpEVaaD4bcV',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 54,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '3l7LRnYByPpEVaaD4bch',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 55,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '317LRnYByPpEVaaD4bcu',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 56,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '4F7LRnYByPpEVaaD4bc8',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 57,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '4V7LRnYByPpEVaaD4bdJ',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 58,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '4l7LRnYByPpEVaaD4bdc',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 59,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '417LRnYByPpEVaaD4bdo',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 60,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '5F7LRnYByPpEVaaD4bd2',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 61,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '5V7LRnYByPpEVaaD4beC',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 62,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '5l7LRnYByPpEVaaD4beQ',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 63,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '517LRnYByPpEVaaD4bed',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 64,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '6F7LRnYByPpEVaaD4ber',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 65,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '6V7LRnYByPpEVaaD4be4',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 66,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '6l7LRnYByPpEVaaD4bfG',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 67,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '617LRnYByPpEVaaD4bfT',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 68,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '7F7LRnYByPpEVaaD4bfg',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 69,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '7V7LRnYByPpEVaaD4bft',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 70,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '7l7LRnYByPpEVaaD4bf7',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 71,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '717LRnYByPpEVaaD4rcH',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 72,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '8F7LRnYByPpEVaaD4rcV',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 73,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '8V7LRnYByPpEVaaD4rch',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 74,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '8l7LRnYByPpEVaaD4rcv',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 75,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '817LRnYByPpEVaaD4rc8',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 76,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '9F7LRnYByPpEVaaD4rdJ',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 77,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '9V7LRnYByPpEVaaD4rdY',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 78,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '9l7LRnYByPpEVaaD4rdq',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 79,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '917LRnYByPpEVaaD4rd9',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 80,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '-F7LRnYByPpEVaaD4reP',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 81,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '-V7LRnYByPpEVaaD4reb',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 82,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '-l7LRnYByPpEVaaD4rep',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 83,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '-17LRnYByPpEVaaD4re2',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 84,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '_F7LRnYByPpEVaaD4rfE',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 85,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '_V7LRnYByPpEVaaD4rfR',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 86,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '_l7LRnYByPpEVaaD4rfl',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 87,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': '_17LRnYByPpEVaaD4rfy',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 88,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'AF7LRnYByPpEVaaD4rj_',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 89,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'AV7LRnYByPpEVaaD47gM',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 90,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Al7LRnYByPpEVaaD47ga',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 91,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'A17LRnYByPpEVaaD47gm',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 92,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'BF7LRnYByPpEVaaD47gz',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 93,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'BV7LRnYByPpEVaaD47hA',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 94,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Bl7LRnYByPpEVaaD47hN',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 95,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'B17LRnYByPpEVaaD47ha',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 96,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'CF7LRnYByPpEVaaD47hn',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 97,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'CV7LRnYByPpEVaaD47h5',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 98,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Cl7LRnYByPpEVaaD47iH',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 99,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'C17LRnYByPpEVaaD47iU',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 100,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'DF7LRnYByPpEVaaD47ii',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 101,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'DV7LRnYByPpEVaaD47iu',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 102,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Dl7LRnYByPpEVaaD47i8',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 103,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'D17LRnYByPpEVaaD47jK',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 104,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'EF7LRnYByPpEVaaD47jX',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 105,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'EV7LRnYByPpEVaaD47jk',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 106,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'El7LRnYByPpEVaaD47jy',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 107,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'E17LRnYByPpEVaaD47j_',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 108,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'FF7LRnYByPpEVaaD5LgM',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 109,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'FV7LRnYByPpEVaaD5LgZ',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 110,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Fl7LRnYByPpEVaaD5Lgt',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 111,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'F17LRnYByPpEVaaD5Lg6',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 112,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'GF7LRnYByPpEVaaD5LhH',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 113,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'GV7LRnYByPpEVaaD5Lha',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 114,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Gl7LRnYByPpEVaaD5Lhn',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 115,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'G17LRnYByPpEVaaD5Lh0',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 116,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'HF7LRnYByPpEVaaD5LiH',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 117,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'HV7LRnYByPpEVaaD5LiU',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 118,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Hl7LRnYByPpEVaaD5Lii',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 119,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'H17LRnYByPpEVaaD5Liu',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 120,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'IF7LRnYByPpEVaaD5Li7',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 121,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'IV7LRnYByPpEVaaD5LjI',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 122,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Il7LRnYByPpEVaaD5LjW',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 123,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'I17LRnYByPpEVaaD5Ljh',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 124,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'JF7LRnYByPpEVaaD5Ljv',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 125,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'JV7LRnYByPpEVaaD5Lj7',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 126,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Jl7LRnYByPpEVaaD5bgJ',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 127,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'J17LRnYByPpEVaaD5bgV',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 128,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'KF7LRnYByPpEVaaD5bgi',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 129,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'KV7LRnYByPpEVaaD5bgw',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 130,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Kl7LRnYByPpEVaaD5bg-',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 131,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'K17LRnYByPpEVaaD5bhN',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 132,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'LF7LRnYByPpEVaaD5bhc',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 133,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'LV7LRnYByPpEVaaD5bhv',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 134,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Ll7LRnYByPpEVaaD5bh9',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 135,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'L17LRnYByPpEVaaD5biU',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 136,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'MF7LRnYByPpEVaaD5bii',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 137,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'MV7LRnYByPpEVaaD5bix',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 138,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Ml7LRnYByPpEVaaD5bi_',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 139,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'M17LRnYByPpEVaaD5bjM',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 140,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'NF7LRnYByPpEVaaD5bjZ',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 141,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'NV7LRnYByPpEVaaD5bjm',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 142,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Nl7LRnYByPpEVaaD5bj0',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 143,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'N17LRnYByPpEVaaD5rgB',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 144,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'OF7LRnYByPpEVaaD5rgP',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 145,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'OV7LRnYByPpEVaaD5rgc',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 146,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Ol7LRnYByPpEVaaD5rgq',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 147,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'O17LRnYByPpEVaaD5rg3',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 148,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'PF7LRnYByPpEVaaD5rhE',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 149,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'PV7LRnYByPpEVaaD5rhR',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 150,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Pl7LRnYByPpEVaaD5rhe',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 151,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'P17LRnYByPpEVaaD5rhr',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 152,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'QF7LRnYByPpEVaaD5rh5',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 153,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'QV7LRnYByPpEVaaD5riG',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 154,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Ql7LRnYByPpEVaaD5riU',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 155,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Q17LRnYByPpEVaaD5rih',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 156,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'RF7LRnYByPpEVaaD5riu',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 157,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'RV7LRnYByPpEVaaD5ri7',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 158,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Rl7LRnYByPpEVaaD5rjI',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 159,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'R17LRnYByPpEVaaD5rjV',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 160,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'SF7LRnYByPpEVaaD5rjh',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 161,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'SV7LRnYByPpEVaaD5rju',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 162,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Sl7LRnYByPpEVaaD5rj7',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 163,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'S17LRnYByPpEVaaD57gI',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 164,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'TF7LRnYByPpEVaaD57gV',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 165,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'TV7LRnYByPpEVaaD57gi',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 166,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Tl7LRnYByPpEVaaD57gv',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 167,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'T17LRnYByPpEVaaD57g7',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 168,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'UF7LRnYByPpEVaaD57hI',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 169,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'UV7LRnYByPpEVaaD57hW',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 170,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Ul7LRnYByPpEVaaD57hi',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 171,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'U17LRnYByPpEVaaD57hv',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 172,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'VF7LRnYByPpEVaaD57h8',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 173,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'VV7LRnYByPpEVaaD57iJ',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 174,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Vl7LRnYByPpEVaaD57iW',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 175,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'V17LRnYByPpEVaaD57ij',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 176,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'WF7LRnYByPpEVaaD57iw',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 177,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'WV7LRnYByPpEVaaD57i9',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 178,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Wl7LRnYByPpEVaaD57jJ',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 179,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'W17LRnYByPpEVaaD57jW',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 180,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'XF7LRnYByPpEVaaD57jk',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 181,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'XV7LRnYByPpEVaaD57jy',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 182,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Xl7LRnYByPpEVaaD6LgE',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 183,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'X17LRnYByPpEVaaD6LgR',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 184,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'YF7LRnYByPpEVaaD6Lge',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 185,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'YV7LRnYByPpEVaaD6Lgr',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 186,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Yl7LRnYByPpEVaaD6Lg4',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 187,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Y17LRnYByPpEVaaD6LhF',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 188,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'ZF7LRnYByPpEVaaD6LhS',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 189,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'ZV7LRnYByPpEVaaD6Lhf',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 190,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Zl7LRnYByPpEVaaD6Lhx',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 191,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'Z17LRnYByPpEVaaD6Lh-',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 192,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'aF7LRnYByPpEVaaD6LiL',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 193,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'aV7LRnYByPpEVaaD6LiY',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 194,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'al7LRnYByPpEVaaD6Lil',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 195,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'a17LRnYByPpEVaaD6Lix',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 196,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'bF7LRnYByPpEVaaD6Li-',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 197,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'bV7LRnYByPpEVaaD6LjL',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 198,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'bl7LRnYByPpEVaaD6LjY',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 199,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'b17LRnYByPpEVaaD6Ljl',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 200,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'cF7LRnYByPpEVaaD6Ljy',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 201,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'cV7LRnYByPpEVaaD6Lj_',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 202,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'cl7LRnYByPpEVaaD6bgM',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 203,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'c17LRnYByPpEVaaD6bgZ',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 204,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'dF7LRnYByPpEVaaD6bgn',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 205,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'dV7LRnYByPpEVaaD6bg1',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 206,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'dl7LRnYByPpEVaaD6bhE',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 207,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'd17LRnYByPpEVaaD6bhU',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 208,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'eF7LRnYByPpEVaaD6bhm',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 209,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'eV7LRnYByPpEVaaD6bh0',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 210,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'el7LRnYByPpEVaaD6biA',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 211,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'e17LRnYByPpEVaaD6biO',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 212,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'fF7LRnYByPpEVaaD6bib',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 213,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'fV7LRnYByPpEVaaD6bio',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 214,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'fl7LRnYByPpEVaaD6bi1',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 215,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'f17LRnYByPpEVaaD6bjC',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 216,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'gF7LRnYByPpEVaaD6bjP',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 217,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'gV7LRnYByPpEVaaD6bjc',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 218,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'gl7LRnYByPpEVaaD6bjp',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 219,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'g17LRnYByPpEVaaD6bj3',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 220,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'hF7LRnYByPpEVaaD6rgE',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 221,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'hV7LRnYByPpEVaaD6rgR',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 222,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'hl7LRnYByPpEVaaD6rgk',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 223,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'h17LRnYByPpEVaaD6rgy',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 224,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'iF7LRnYByPpEVaaD6rg_',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
# ...
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'cF7MRnYByPpEVaaDBLrD',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 713,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'cV7MRnYByPpEVaaDBLrX',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 714,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'cl7MRnYByPpEVaaDBLrk',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 715,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'c17MRnYByPpEVaaDBLry',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 716,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'dF7MRnYByPpEVaaDBLr_',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 717,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'dV7MRnYByPpEVaaDBboO',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 718,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'dl7MRnYByPpEVaaDBbok',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 719,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'd17MRnYByPpEVaaDBbo0',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 720,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'eF7MRnYByPpEVaaDBbpA',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 721,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'eV7MRnYByPpEVaaDBbpO',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 722,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'el7MRnYByPpEVaaDBbpb',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 723,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'e17MRnYByPpEVaaDBbpp',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 724,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'fF7MRnYByPpEVaaDBbp2',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 725,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'fV7MRnYByPpEVaaDBbqD',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 726,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'fl7MRnYByPpEVaaDBbqW',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 727,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'f17MRnYByPpEVaaDBbqj',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 728,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'gF7MRnYByPpEVaaDBbq1',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 729,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'gV7MRnYByPpEVaaDBbrC',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 730,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'gl7MRnYByPpEVaaDBbrP',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 731,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'g17MRnYByPpEVaaDBbrc',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 732,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'hF7MRnYByPpEVaaDBbry',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 733,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'hV7MRnYByPpEVaaDBroK',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 734,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'hl7MRnYByPpEVaaDBrog',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 735,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'h17MRnYByPpEVaaDBro4',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 736,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'iF7MRnYByPpEVaaDBrpE',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 737,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'iV7MRnYByPpEVaaDBrpS',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 738,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'il7MRnYByPpEVaaDBrpf',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 739,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'i17MRnYByPpEVaaDBrpx',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 740,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'jF7MRnYByPpEVaaDBrp-',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 741,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'jV7MRnYByPpEVaaDBrqM',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 742,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'jl7MRnYByPpEVaaDBrqZ',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 743,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'j17MRnYByPpEVaaDBrqn',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 744,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'kF7MRnYByPpEVaaDBrq0',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 745,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'kV7MRnYByPpEVaaDBrrC',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 746,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'kl7MRnYByPpEVaaDBrrP',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 747,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'k17MRnYByPpEVaaDBrrd',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 748,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'lF7MRnYByPpEVaaDBrrp',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 749,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'lV7MRnYByPpEVaaDBrr3',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 750,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'll7MRnYByPpEVaaDB7oE',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 751,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'l17MRnYByPpEVaaDB7oR',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 752,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'mF7MRnYByPpEVaaDB7of',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 753,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'mV7MRnYByPpEVaaDB7os',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 754,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'ml7MRnYByPpEVaaDB7o6',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 755,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'm17MRnYByPpEVaaDB7pH',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 756,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'nF7MRnYByPpEVaaDB7pV',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 757,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'nV7MRnYByPpEVaaDB7pi',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 758,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'nl7MRnYByPpEVaaDB7pv',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 759,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'n17MRnYByPpEVaaDB7qB',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 760,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'oF7MRnYByPpEVaaDB7qP',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 761,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'oV7MRnYByPpEVaaDB7qc',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 762,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'ol7MRnYByPpEVaaDB7qq',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 763,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'o17MRnYByPpEVaaDB7q9',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 764,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'pF7MRnYByPpEVaaDB7rK',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 765,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'pV7MRnYByPpEVaaDB7rX',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 766,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'pl7MRnYByPpEVaaDB7ro',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 767,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'p17MRnYByPpEVaaDCLoE',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 768,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'qF7MRnYByPpEVaaDCLoR',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 769,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'qV7MRnYByPpEVaaDCLoe',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 770,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'ql7MRnYByPpEVaaDCLor',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 771,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'q17MRnYByPpEVaaDCLo5',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 772,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'rF7MRnYByPpEVaaDCLpG',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 773,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'rV7MRnYByPpEVaaDCLpT',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 774,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'rl7MRnYByPpEVaaDCLph',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 775,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'r17MRnYByPpEVaaDCLpu',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 776,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'sF7MRnYByPpEVaaDCLp7',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 777,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'sV7MRnYByPpEVaaDCLqJ',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 778,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'sl7MRnYByPpEVaaDCLqW',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 779,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 's17MRnYByPpEVaaDCLqk',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 780,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'tF7MRnYByPpEVaaDCLqx',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 781,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'tV7MRnYByPpEVaaDCLq-',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 782,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'tl7MRnYByPpEVaaDCLrL',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 783,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 't17MRnYByPpEVaaDCLre',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 784,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'uF7MRnYByPpEVaaDCLrq',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 785,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'uV7MRnYByPpEVaaDCLr4',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 786,
#   '_primary_term': 1},
#  {'_index': 'tickers',
#   '_type': '_doc',
#   '_id': 'ul7MRnYByPpEVaaDCboF',
#   '_version': 1,
#   'result': 'created',
#   '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#   '_seq_no': 787,
#   '_primary_term': 1}]

# %% [markdown]
# # Search
#
# ## Match Query
#
# 완전 일치해야 합니다.<br>
# 예를 들어 '000660'은 검색이 되지만 '00066'은 앞글자가 맞더라도 검색이 안됩니다.

# %%
query = {
    'query': {
        'match': {
            'ticker': '000660'
        }
    }
}
es.search(index='tickers', body=query)
# Out:
# {'took': 2,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 1, 'relation': 'eq'},
#   'max_score': 6.2653008,
#   'hits': [{'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'DV7LRnYByPpEVaaD47iu',
#     '_score': 6.2653008,
#     '_source': {'name': 'SK하이닉스',
#      'ticker': '000660',
#      'suggest': {'input': ['SK', '하이닉스'], 'weight': 1}}}]}}

# %% [markdown]
# ## Match ALL

# %%
es.search(index='tickers', 
          body={'query': {'match_all': {}}}, 
          size=1000)
# Out:
# {'took': 24,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 788, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '417LRnYByPpEVaaD_bka',
#     '_score': 1.0,
#     '_source': {'name': '지투알',
#      'ticker': '035000',
#      'suggest': {'input': ['지투알'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '5F7LRnYByPpEVaaD_bkp',
#     '_score': 1.0,
#     '_source': {'name': '진도',
#      'ticker': '088790',
#      'suggest': {'input': ['진도'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '5V7LRnYByPpEVaaD_bk4',
#     '_score': 1.0,
#     '_source': {'name': '진양산업',
#      'ticker': '003780',
#      'suggest': {'input': ['진양', '산업'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '5l7LRnYByPpEVaaD_blE',
#     '_score': 1.0,
#     '_source': {'name': '진양폴리',
#      'ticker': '010640',
#      'suggest': {'input': ['진양', '폴리'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '517LRnYByPpEVaaD_blS',
#     '_score': 1.0,
#     '_source': {'name': '진양홀딩스',
#      'ticker': '100250',
#      'suggest': {'input': ['진양', '홀딩스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '6F7LRnYByPpEVaaD_blf',
#     '_score': 1.0,
#     '_source': {'name': '진양화학',
#      'ticker': '051630',
#      'suggest': {'input': ['진양', '화학'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '6V7LRnYByPpEVaaD_blu',
#     '_score': 1.0,
#     '_source': {'name': '진에어',
#      'ticker': '272450',
#      'suggest': {'input': ['진에어'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '6l7LRnYByPpEVaaD_bl7',
#     '_score': 1.0,
#     '_source': {'name': '진원생명과학',
#      'ticker': '011000',
#      'suggest': {'input': ['진원', '생명', '과학'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '617LRnYByPpEVaaD_bmI',
#     '_score': 1.0,
#     '_source': {'name': '진흥기업',
#      'ticker': '002780',
#      'suggest': {'input': ['진흥기업'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '7F7LRnYByPpEVaaD_bmW',
#     '_score': 1.0,
#     '_source': {'name': '참엔지니어링',
#      'ticker': '009310',
#      'suggest': {'input': ['참', '엔지니어링'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '7V7LRnYByPpEVaaD_bmj',
#     '_score': 1.0,
#     '_source': {'name': '천일고속',
#      'ticker': '000650',
#      'suggest': {'input': ['천일고속'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '7l7LRnYByPpEVaaD_bmx',
#     '_score': 1.0,
#     '_source': {'name': '센트럴인사이트',
#      'ticker': '012600',
#      'suggest': {'input': ['센트럴', '인사이트'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '717LRnYByPpEVaaD_bm-',
#     '_score': 1.0,
#     '_source': {'name': '체시스',
#      'ticker': '033250',
#      'suggest': {'input': ['체시스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '8F7LRnYByPpEVaaD_bnL',
#     '_score': 1.0,
#     '_source': {'name': '카카오',
#      'ticker': '035720',
#      'suggest': {'input': ['카카오'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '8V7LRnYByPpEVaaD_bnY',
#     '_score': 1.0,
#     '_source': {'name': '카프로',
#      'ticker': '006380',
#      'suggest': {'input': ['카프로'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '8l7LRnYByPpEVaaD_bnm',
#     '_score': 1.0,
#     '_source': {'name': '컨버즈',
#      'ticker': '109070',
#      'suggest': {'input': ['컨', '버즈'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '817LRnYByPpEVaaD_bn4',
#     '_score': 1.0,
#     '_source': {'name': '케이씨',
#      'ticker': '029460',
#      'suggest': {'input': ['케이', '씨'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '9F7LRnYByPpEVaaD_rkF',
#     '_score': 1.0,
#     '_source': {'name': '케이씨텍',
#      'ticker': '281820',
#      'suggest': {'input': ['케이', '씨', '텍'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '9V7LRnYByPpEVaaD_rkR',
#     '_score': 1.0,
#     '_source': {'name': '케이탑리츠',
#      'ticker': '145270',
#      'suggest': {'input': ['케이', '탑', '리츠'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '9l7LRnYByPpEVaaD_rke',
#     '_score': 1.0,
#     '_source': {'name': 'KTis',
#      'ticker': '058860',
#      'suggest': {'input': ['KTis'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '917LRnYByPpEVaaD_rkr',
#     '_score': 1.0,
#     '_source': {'name': '코리아써키트',
#      'ticker': '007810',
#      'suggest': {'input': ['코리아', '써', '키트'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '-F7LRnYByPpEVaaD_rk5',
#     '_score': 1.0,
#     '_source': {'name': '코리아오토글라스',
#      'ticker': '152330',
#      'suggest': {'input': ['코리아', '오토', '글라스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '-V7LRnYByPpEVaaD_rlG',
#     '_score': 1.0,
#     '_source': {'name': '코리안리',
#      'ticker': '003690',
#      'suggest': {'input': ['코리', '안리'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '-l7LRnYByPpEVaaD_rlT',
#     '_score': 1.0,
#     '_source': {'name': '코스맥스',
#      'ticker': '192820',
#      'suggest': {'input': ['코스', '맥스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '-17LRnYByPpEVaaD_rlg',
#     '_score': 1.0,
#     '_source': {'name': '코스맥스비티아이',
#      'ticker': '044820',
#      'suggest': {'input': ['코스', '맥스', '비티', '아이'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '_F7LRnYByPpEVaaD_rlt',
#     '_score': 1.0,
#     '_source': {'name': '코스모신소재',
#      'ticker': '005070',
#      'suggest': {'input': ['코스모신소재'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '_V7LRnYByPpEVaaD_rl6',
#     '_score': 1.0,
#     '_source': {'name': '코스모화학',
#      'ticker': '005420',
#      'suggest': {'input': ['코스모', '화학'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '_l7LRnYByPpEVaaD_rmI',
#     '_score': 1.0,
#     '_source': {'name': '코아스',
#      'ticker': '071950',
#      'suggest': {'input': ['코', '아스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '_17LRnYByPpEVaaD_rmU',
#     '_score': 1.0,
#     '_source': {'name': '코오롱',
#      'ticker': '002020',
#      'suggest': {'input': ['코오롱'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'AF7LRnYByPpEVaaD_rqi',
#     '_score': 1.0,
#     '_source': {'name': '코오롱글로벌',
#      'ticker': '003070',
#      'suggest': {'input': ['코오롱', '글로벌'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'AV7LRnYByPpEVaaD_rqv',
#     '_score': 1.0,
#     '_source': {'name': '코오롱머티리얼',
#      'ticker': '144620',
#      'suggest': {'input': ['코오롱', '머티', '리얼'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Al7LRnYByPpEVaaD_rq8',
#     '_score': 1.0,
#     '_source': {'name': '코오롱인더',
#      'ticker': '120110',
#      'suggest': {'input': ['코오롱', '인더'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'A17LRnYByPpEVaaD_rrK',
#     '_score': 1.0,
#     '_source': {'name': '코오롱플라스틱',
#      'ticker': '138490',
#      'suggest': {'input': ['코오롱', '플라스틱'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'BF7LRnYByPpEVaaD_rrY',
#     '_score': 1.0,
#     '_source': {'name': '코웨이',
#      'ticker': '021240',
#      'suggest': {'input': ['코웨이'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'BV7LRnYByPpEVaaD_rrl',
#     '_score': 1.0,
#     '_source': {'name': '콤텍시스템',
#      'ticker': '031820',
#      'suggest': {'input': ['콤', '텍', '시스템'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Bl7LRnYByPpEVaaD_rry',
#     '_score': 1.0,
#     '_source': {'name': '쿠쿠홀딩스',
#      'ticker': '192400',
#      'suggest': {'input': ['쿠쿠', '홀딩스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'B17LRnYByPpEVaaD_7oA',
#     '_score': 1.0,
#     '_source': {'name': '쿠쿠홈시스',
#      'ticker': '284740',
#      'suggest': {'input': ['쿠쿠', '홈', '시스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'CF7LRnYByPpEVaaD_7oO',
#     '_score': 1.0,
#     '_source': {'name': '큐로',
#      'ticker': '015590',
#      'suggest': {'input': ['큐', '로'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'CV7LRnYByPpEVaaD_7ob',
#     '_score': 1.0,
#     '_source': {'name': '크라운제과',
#      'ticker': '264900',
#      'suggest': {'input': ['크라운제과'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Cl7LRnYByPpEVaaD_7oo',
#     '_score': 1.0,
#     '_source': {'name': '크라운해태홀딩스',
#      'ticker': '005740',
#      'suggest': {'input': ['크라운', '해태', '홀딩스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'C17LRnYByPpEVaaD_7o2',
#     '_score': 1.0,
#     '_source': {'name': '키다리스튜디오',
#      'ticker': '020120',
#      'suggest': {'input': ['키다리', '스튜디오'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'DF7LRnYByPpEVaaD_7pT',
#     '_score': 1.0,
#     '_source': {'name': '키움증권',
#      'ticker': '039490',
#      'suggest': {'input': ['키움증권'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'DV7LRnYByPpEVaaD_7pg',
#     '_score': 1.0,
#     '_source': {'name': '키위미디어그룹',
#      'ticker': '012170',
#      'suggest': {'input': ['키위', '미디어', '그룹'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Dl7LRnYByPpEVaaD_7pv',
#     '_score': 1.0,
#     '_source': {'name': '태경산업',
#      'ticker': '015890',
#      'suggest': {'input': ['태경', '산업'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'D17LRnYByPpEVaaD_7p8',
#     '_score': 1.0,
#     '_source': {'name': '태경케미컬',
#      'ticker': '006890',
#      'suggest': {'input': ['태경', '케미컬'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'EF7LRnYByPpEVaaD_7qJ',
#     '_score': 1.0,
#     '_source': {'name': '태광산업',
#      'ticker': '003240',
#      'suggest': {'input': ['태', '광산업'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'EV7LRnYByPpEVaaD_7qc',
#     '_score': 1.0,
#     '_source': {'name': '태림포장',
#      'ticker': '011280',
#      'suggest': {'input': ['태림', '포장'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'El7LRnYByPpEVaaD_7qq',
#     '_score': 1.0,
#     '_source': {'name': '태양금속',
#      'ticker': '004100',
#      'suggest': {'input': ['태양', '금속'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'E17LRnYByPpEVaaD_7q9',
#     '_score': 1.0,
#     '_source': {'name': '태영건설',
#      'ticker': '009410',
#      'suggest': {'input': ['태영', '건설'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'FF7LRnYByPpEVaaD_7rL',
#     '_score': 1.0,
#     '_source': {'name': '태원물산',
#      'ticker': '001420',
#      'suggest': {'input': ['태원', '물산'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'FV7LRnYByPpEVaaD_7rY',
#     '_score': 1.0,
#     '_source': {'name': '태평양물산',
#      'ticker': '007980',
#      'suggest': {'input': ['태평양', '물산'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Fl7LRnYByPpEVaaD_7rr',
#     '_score': 1.0,
#     '_source': {'name': '테이팩스',
#      'ticker': '055490',
#      'suggest': {'input': ['테이', '팩스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'F17LRnYByPpEVaaD_7r5',
#     '_score': 1.0,
#     '_source': {'name': '텔코웨어',
#      'ticker': '078000',
#      'suggest': {'input': ['텔', '코', '웨', '어'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'GF7MRnYByPpEVaaDALoM',
#     '_score': 1.0,
#     '_source': {'name': '토니모리',
#      'ticker': '214420',
#      'suggest': {'input': ['토니', '모리'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'GV7MRnYByPpEVaaDALoZ',
#     '_score': 1.0,
#     '_source': {'name': '트러스제7호',
#      'ticker': '140890',
#      'suggest': {'input': ['트러스', '제', '7', '호'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Gl7MRnYByPpEVaaDALon',
#     '_score': 1.0,
#     '_source': {'name': '티에이치엔',
#      'ticker': '019180',
#      'suggest': {'input': ['티', '에', '이치엔'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'G17MRnYByPpEVaaDALo0',
#     '_score': 1.0,
#     '_source': {'name': '티웨이항공',
#      'ticker': '091810',
#      'suggest': {'input': ['티웨이항공'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'HF7MRnYByPpEVaaDALpC',
#     '_score': 1.0,
#     '_source': {'name': '티웨이홀딩스',
#      'ticker': '004870',
#      'suggest': {'input': ['티', '웨이', '홀딩스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'HV7MRnYByPpEVaaDALpQ',
#     '_score': 1.0,
#     '_source': {'name': '파미셀',
#      'ticker': '005690',
#      'suggest': {'input': ['파미', '셀'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Hl7MRnYByPpEVaaDALpd',
#     '_score': 1.0,
#     '_source': {'name': '팜스코',
#      'ticker': '036580',
#      'suggest': {'input': ['팜', '스코'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'H17MRnYByPpEVaaDALpq',
#     '_score': 1.0,
#     '_source': {'name': '팬오션',
#      'ticker': '028670',
#      'suggest': {'input': ['팬', '오', '션'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'IF7MRnYByPpEVaaDALp4',
#     '_score': 1.0,
#     '_source': {'name': '퍼스텍',
#      'ticker': '010820',
#      'suggest': {'input': ['퍼스텍'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'IV7MRnYByPpEVaaDALqF',
#     '_score': 1.0,
#     '_source': {'name': '퍼시스',
#      'ticker': '016800',
#      'suggest': {'input': ['퍼시스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Il7MRnYByPpEVaaDALqS',
#     '_score': 1.0,
#     '_source': {'name': '페이퍼코리아',
#      'ticker': '001020',
#      'suggest': {'input': ['페이퍼', '코리아'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'I17MRnYByPpEVaaDALqf',
#     '_score': 1.0,
#     '_source': {'name': '평화산업',
#      'ticker': '090080',
#      'suggest': {'input': ['평화', '산업'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'JF7MRnYByPpEVaaDALqs',
#     '_score': 1.0,
#     '_source': {'name': '평화홀딩스',
#      'ticker': '010770',
#      'suggest': {'input': ['평화', '홀딩스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'JV7MRnYByPpEVaaDALq6',
#     '_score': 1.0,
#     '_source': {'name': '포스코강판',
#      'ticker': '058430',
#      'suggest': {'input': ['포스코강판'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Jl7MRnYByPpEVaaDALrH',
#     '_score': 1.0,
#     '_source': {'name': '포스코인터내셔널',
#      'ticker': '047050',
#      'suggest': {'input': ['포스코', '인터내셔널'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'J17MRnYByPpEVaaDALrU',
#     '_score': 1.0,
#     '_source': {'name': '폴루스바이오팜',
#      'ticker': '007630',
#      'suggest': {'input': ['폴', '루스', '바이오팜'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'KF7MRnYByPpEVaaDALrh',
#     '_score': 1.0,
#     '_source': {'name': '풀무원',
#      'ticker': '017810',
#      'suggest': {'input': ['풀무원'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'KV7MRnYByPpEVaaDALrv',
#     '_score': 1.0,
#     '_source': {'name': '풍산',
#      'ticker': '103140',
#      'suggest': {'input': ['풍산'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Kl7MRnYByPpEVaaDALr8',
#     '_score': 1.0,
#     '_source': {'name': '풍산홀딩스',
#      'ticker': '005810',
#      'suggest': {'input': ['풍산홀딩스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'T17LRnYByPpEVaaD9bky',
#     '_score': 1.0,
#     '_source': {'name': '신원',
#      'ticker': '009270',
#      'suggest': {'input': ['신원'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'UF7LRnYByPpEVaaD9blB',
#     '_score': 1.0,
#     '_source': {'name': '신일전자',
#      'ticker': '002700',
#      'suggest': {'input': ['신일', '전자'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'UV7LRnYByPpEVaaD9blO',
#     '_score': 1.0,
#     '_source': {'name': '신풍제약',
#      'ticker': '019170',
#      'suggest': {'input': ['신풍', '제약'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Ul7LRnYByPpEVaaD9bla',
#     '_score': 1.0,
#     '_source': {'name': '신풍제지',
#      'ticker': '002870',
#      'suggest': {'input': ['신풍', '제지'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'U17LRnYByPpEVaaD9bls',
#     '_score': 1.0,
#     '_source': {'name': '신한',
#      'ticker': '005450',
#      'suggest': {'input': ['신한'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'VF7LRnYByPpEVaaD9bl5',
#     '_score': 1.0,
#     '_source': {'name': '신한알파리츠',
#      'ticker': '293940',
#      'suggest': {'input': ['신한', '알파', '리츠'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'VV7LRnYByPpEVaaD9bmG',
#     '_score': 1.0,
#     '_source': {'name': '신한지주',
#      'ticker': '055550',
#      'suggest': {'input': ['신한', '지주'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Vl7LRnYByPpEVaaD9bmZ',
#     '_score': 1.0,
#     '_source': {'name': '신화실업',
#      'ticker': '001770',
#      'suggest': {'input': ['신화', '실업'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'V17LRnYByPpEVaaD9bmm',
#     '_score': 1.0,
#     '_source': {'name': '신흥',
#      'ticker': '004080',
#      'suggest': {'input': ['신흥'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'WF7LRnYByPpEVaaD9bm0',
#     '_score': 1.0,
#     '_source': {'name': '쌍방울',
#      'ticker': '102280',
#      'suggest': {'input': ['쌍방울'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'WV7LRnYByPpEVaaD9bnA',
#     '_score': 1.0,
#     '_source': {'name': '쌍용양회',
#      'ticker': '003410',
#      'suggest': {'input': ['쌍용', '양회'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Wl7LRnYByPpEVaaD9bnO',
#     '_score': 1.0,
#     '_source': {'name': '쌍용차',
#      'ticker': '003620',
#      'suggest': {'input': ['쌍용', '차'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'W17LRnYByPpEVaaD9bnb',
#     '_score': 1.0,
#     '_source': {'name': '써니전자',
#      'ticker': '004770',
#      'suggest': {'input': ['써니', '전자'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'XF7LRnYByPpEVaaD9bnp',
#     '_score': 1.0,
#     '_source': {'name': '씨아이테크',
#      'ticker': '004920',
#      'suggest': {'input': ['씨', '아이', '테크'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'XV7LRnYByPpEVaaD9bn2',
#     '_score': 1.0,
#     '_source': {'name': '씨에스윈드',
#      'ticker': '112610',
#      'suggest': {'input': ['씨', '에스', '윈드'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Xl7LRnYByPpEVaaD9rkD',
#     '_score': 1.0,
#     '_source': {'name': '아남전자',
#      'ticker': '008700',
#      'suggest': {'input': ['아', '남', '전자'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'X17LRnYByPpEVaaD9rkQ',
#     '_score': 1.0,
#     '_source': {'name': '아모레G',
#      'ticker': '002790',
#      'suggest': {'input': ['아모레', 'G'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'YF7LRnYByPpEVaaD9rke',
#     '_score': 1.0,
#     '_source': {'name': '아모레퍼시픽',
#      'ticker': '090430',
#      'suggest': {'input': ['아모레', '퍼시픽'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'YV7LRnYByPpEVaaD9rkr',
#     '_score': 1.0,
#     '_source': {'name': '아세아',
#      'ticker': '002030',
#      'suggest': {'input': ['아', '세아'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Yl7LRnYByPpEVaaD9rk4',
#     '_score': 1.0,
#     '_source': {'name': '아세아시멘트',
#      'ticker': '183190',
#      'suggest': {'input': ['아', '세아', '시멘트'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Y17LRnYByPpEVaaD9rlF',
#     '_score': 1.0,
#     '_source': {'name': '아세아제지',
#      'ticker': '002310',
#      'suggest': {'input': ['아', '세아', '제지'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'ZF7LRnYByPpEVaaD9rlT',
#     '_score': 1.0,
#     '_source': {'name': '아시아나IDT',
#      'ticker': '267850',
#      'suggest': {'input': ['아시아', '나', 'IDT'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'ZV7LRnYByPpEVaaD9rlg',
#     '_score': 1.0,
#     '_source': {'name': '아시아나항공',
#      'ticker': '020560',
#      'suggest': {'input': ['아시아나항공'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Zl7LRnYByPpEVaaD9rlu',
#     '_score': 1.0,
#     '_source': {'name': '아이마켓코리아',
#      'ticker': '122900',
#      'suggest': {'input': ['아이', '마켓', '코리아'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Z17LRnYByPpEVaaD9rl6',
#     '_score': 1.0,
#     '_source': {'name': '아이에스동서',
#      'ticker': '010780',
#      'suggest': {'input': ['아이', '에스', '동서'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'aF7LRnYByPpEVaaD9rmI',
#     '_score': 1.0,
#     '_source': {'name': '아주캐피탈',
#      'ticker': '033660',
#      'suggest': {'input': ['아주', '캐피탈'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'aV7LRnYByPpEVaaD9rmV',
#     '_score': 1.0,
#     '_source': {'name': '인바이오젠',
#      'ticker': '101140',
#      'suggest': {'input': ['인바', '이', '오', '젠'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'al7LRnYByPpEVaaD9rmj',
#     '_score': 1.0,
#     '_source': {'name': '알루코',
#      'ticker': '001780',
#      'suggest': {'input': ['알루코'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'a17LRnYByPpEVaaD9rmv',
#     '_score': 1.0,
#     '_source': {'name': '알보젠코리아',
#      'ticker': '002250',
#      'suggest': {'input': ['알보', '젠', '코리아'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'bF7LRnYByPpEVaaD9rnD',
#     '_score': 1.0,
#     '_source': {'name': '애경산업',
#      'ticker': '018250',
#      'suggest': {'input': ['애경', '산업'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'bV7LRnYByPpEVaaD9rnQ',
#     '_score': 1.0,
#     '_source': {'name': '애경유화',
#      'ticker': '161000',
#      'suggest': {'input': ['애경', '유화'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'bl7LRnYByPpEVaaD9rne',
#     '_score': 1.0,
#     '_source': {'name': '에넥스',
#      'ticker': '011090',
#      'suggest': {'input': ['에넥스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'b17LRnYByPpEVaaD9rnr',
#     '_score': 1.0,
#     '_source': {'name': '에스엘',
#      'ticker': '005850',
#      'suggest': {'input': ['에스', '엘'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'cF7LRnYByPpEVaaD9rn3',
#     '_score': 1.0,
#     '_source': {'name': '에스원',
#      'ticker': '012750',
#      'suggest': {'input': ['에스원'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'cV7LRnYByPpEVaaD97kF',
#     '_score': 1.0,
#     '_source': {'name': '에쓰씨엔지니어링',
#      'ticker': '023960',
#      'suggest': {'input': ['에', '쓰', '씨', '엔지니어링'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'cl7LRnYByPpEVaaD97kS',
#     '_score': 1.0,
#     '_source': {'name': '에어부산',
#      'ticker': '298690',
#      'suggest': {'input': ['에어부산'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'c17LRnYByPpEVaaD97kg',
#     '_score': 1.0,
#     '_source': {'name': '에이리츠',
#      'ticker': '140910',
#      'suggest': {'input': ['에이리', '츠'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'dF7LRnYByPpEVaaD97kt',
#     '_score': 1.0,
#     '_source': {'name': '에이블씨엔씨',
#      'ticker': '078520',
#      'suggest': {'input': ['에이블', '씨', '엔', '씨'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'dV7LRnYByPpEVaaD97k6',
#     '_score': 1.0,
#     '_source': {'name': '에이엔피',
#      'ticker': '015260',
#      'suggest': {'input': ['에이', '엔', '피'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'dl7LRnYByPpEVaaD97lI',
#     '_score': 1.0,
#     '_source': {'name': '에이프로젠 KIC',
#      'ticker': '007460',
#      'suggest': {'input': ['에', '이프로', '젠', 'KIC'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'd17LRnYByPpEVaaD97lW',
#     '_score': 1.0,
#     '_source': {'name': '에이프로젠제약',
#      'ticker': '003060',
#      'suggest': {'input': ['에', '이프로', '젠', '제약'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'eF7LRnYByPpEVaaD97li',
#     '_score': 1.0,
#     '_source': {'name': '엔씨소프트',
#      'ticker': '036570',
#      'suggest': {'input': ['엔', '씨', '소프트'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'eV7LRnYByPpEVaaD97lv',
#     '_score': 1.0,
#     '_source': {'name': '엔에스쇼핑',
#      'ticker': '138250',
#      'suggest': {'input': ['엔에스', '쇼핑'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'el7LRnYByPpEVaaD97l8',
#     '_score': 1.0,
#     '_source': {'name': '엔케이',
#      'ticker': '085310',
#      'suggest': {'input': ['엔', '케이'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'e17LRnYByPpEVaaD97mJ',
#     '_score': 1.0,
#     '_source': {'name': '엔케이물산',
#      'ticker': '009810',
#      'suggest': {'input': ['엔', '케이', '물산'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'fF7LRnYByPpEVaaD97mW',
#     '_score': 1.0,
#     '_source': {'name': '엘브이엠씨홀딩스',
#      'ticker': '900140',
#      'suggest': {'input': ['엘', '브', '이엠씨', '홀딩스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'fV7LRnYByPpEVaaD97mj',
#     '_score': 1.0,
#     '_source': {'name': '영보화학',
#      'ticker': '014440',
#      'suggest': {'input': ['영보', '화학'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'fl7LRnYByPpEVaaD97mv',
#     '_score': 1.0,
#     '_source': {'name': '영원무역',
#      'ticker': '111770',
#      'suggest': {'input': ['영원', '무역'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'f17LRnYByPpEVaaD97m9',
#     '_score': 1.0,
#     '_source': {'name': '영원무역홀딩스',
#      'ticker': '009970',
#      'suggest': {'input': ['영원', '무역', '홀딩스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'gF7LRnYByPpEVaaD97nJ',
#     '_score': 1.0,
#     '_source': {'name': '영진약품',
#      'ticker': '003520',
#      'suggest': {'input': ['영진', '약품'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'gV7LRnYByPpEVaaD97nX',
#     '_score': 1.0,
#     '_source': {'name': '영풍',
#      'ticker': '000670',
#      'suggest': {'input': ['영풍'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'gl7LRnYByPpEVaaD97nk',
#     '_score': 1.0,
#     '_source': {'name': '영풍제지',
#      'ticker': '006740',
#      'suggest': {'input': ['영풍', '제지'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'g17LRnYByPpEVaaD97nx',
#     '_score': 1.0,
#     '_source': {'name': '영화금속',
#      'ticker': '012280',
#      'suggest': {'input': ['영화', '금속'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'hF7LRnYByPpEVaaD-LkE',
#     '_score': 1.0,
#     '_source': {'name': '영흥',
#      'ticker': '012160',
#      'suggest': {'input': ['영흥'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'hV7LRnYByPpEVaaD-LkS',
#     '_score': 1.0,
#     '_source': {'name': '예스코홀딩스',
#      'ticker': '015360',
#      'suggest': {'input': ['예', '스코', '홀딩스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'hl7LRnYByPpEVaaD-Lkk',
#     '_score': 1.0,
#     '_source': {'name': '오뚜기',
#      'ticker': '007310',
#      'suggest': {'input': ['오뚜기'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'h17LRnYByPpEVaaD-Lk4',
#     '_score': 1.0,
#     '_source': {'name': '오렌지라이프',
#      'ticker': '079440',
#      'suggest': {'input': ['오렌지', '라이프'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'iF7LRnYByPpEVaaD-LlF',
#     '_score': 1.0,
#     '_source': {'name': '오리엔트바이오',
#      'ticker': '002630',
#      'suggest': {'input': ['오리엔트', '바이오'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'iV7LRnYByPpEVaaD-LlX',
#     '_score': 1.0,
#     '_source': {'name': '오리온',
#      'ticker': '271560',
#      'suggest': {'input': ['오리온'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'il7LRnYByPpEVaaD-Llk',
#     '_score': 1.0,
#     '_source': {'name': '오리온홀딩스',
#      'ticker': '001800',
#      'suggest': {'input': ['오리온', '홀딩스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'i17LRnYByPpEVaaD-Ll3',
#     '_score': 1.0,
#     '_source': {'name': '용평리조트',
#      'ticker': '070960',
#      'suggest': {'input': ['용평', '리조트'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'jF7LRnYByPpEVaaD-LmD',
#     '_score': 1.0,
#     '_source': {'name': '우리금융지주',
#      'ticker': '316140',
#      'suggest': {'input': ['우리', '금융', '지주'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'jV7LRnYByPpEVaaD-LmW',
#     '_score': 1.0,
#     '_source': {'name': '우리들제약',
#      'ticker': '004720',
#      'suggest': {'input': ['우리', '들', '제약'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'jl7LRnYByPpEVaaD-Lmj',
#     '_score': 1.0,
#     '_source': {'name': '우리들휴브레인',
#      'ticker': '118000',
#      'suggest': {'input': ['우리', '들', '휴', '브레인'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'j17LRnYByPpEVaaD-Lmw',
#     '_score': 1.0,
#     '_source': {'name': '우리종금',
#      'ticker': '010050',
#      'suggest': {'input': ['우리', '종금'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'kF7LRnYByPpEVaaD-Lm9',
#     '_score': 1.0,
#     '_source': {'name': '우성사료',
#      'ticker': '006980',
#      'suggest': {'input': ['우성', '사료'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'kV7LRnYByPpEVaaD-LnJ',
#     '_score': 1.0,
#     '_source': {'name': '우신시스템',
#      'ticker': '017370',
#      'suggest': {'input': ['우신', '시스템'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'kl7LRnYByPpEVaaD-LnX',
#     '_score': 1.0,
#     '_source': {'name': '우진',
#      'ticker': '105840',
#      'suggest': {'input': ['우진'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'k17LRnYByPpEVaaD-Lnj',
#     '_score': 1.0,
#     '_source': {'name': '우진아이엔에스',
#      'ticker': '010400',
#      'suggest': {'input': ['우진', '아이엔에스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'lF7LRnYByPpEVaaD-Lnx',
#     '_score': 1.0,
#     '_source': {'name': '우진플라임',
#      'ticker': '049800',
#      'suggest': {'input': ['우진', '플', '라임'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'lV7LRnYByPpEVaaD-Ln9',
#     '_score': 1.0,
#     '_source': {'name': '웅진',
#      'ticker': '016880',
#      'suggest': {'input': ['웅진'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'll7LRnYByPpEVaaD-bkL',
#     '_score': 1.0,
#     '_source': {'name': '웅진씽크빅',
#      'ticker': '095720',
#      'suggest': {'input': ['웅진씽크빅'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'K17MRnYByPpEVaaDAboU',
#     '_score': 1.0,
#     '_source': {'name': '필룩스',
#      'ticker': '033180',
#      'suggest': {'input': ['필룩스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'LF7MRnYByPpEVaaDAbok',
#     '_score': 1.0,
#     '_source': {'name': '하나금융지주',
#      'ticker': '086790',
#      'suggest': {'input': ['하나', '금융', '지주'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'LV7MRnYByPpEVaaDAboy',
#     '_score': 1.0,
#     '_source': {'name': '하나니켈1호',
#      'ticker': '099340',
#      'suggest': {'input': ['하나', '니켈', '1', '호'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Ll7MRnYByPpEVaaDAbo_',
#     '_score': 1.0,
#     '_source': {'name': '하나니켈2호',
#      'ticker': '099350',
#      'suggest': {'input': ['하나', '니켈', '2', '호'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'L17MRnYByPpEVaaDAbpM',
#     '_score': 1.0,
#     '_source': {'name': '하나제약',
#      'ticker': '293480',
#      'suggest': {'input': ['하나', '제약'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'MF7MRnYByPpEVaaDAbpd',
#     '_score': 1.0,
#     '_source': {'name': '하나투어',
#      'ticker': '039130',
#      'suggest': {'input': ['하나', '투어'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'MV7MRnYByPpEVaaDAbpr',
#     '_score': 1.0,
#     '_source': {'name': '하이골드12호',
#      'ticker': '172580',
#      'suggest': {'input': ['하', '이골드', '12', '호'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Ml7MRnYByPpEVaaDAbp3',
#     '_score': 1.0,
#     '_source': {'name': '하이골드3호',
#      'ticker': '153360',
#      'suggest': {'input': ['하', '이골드', '3', '호'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'M17MRnYByPpEVaaDAbqE',
#     '_score': 1.0,
#     '_source': {'name': '하이골드8호',
#      'ticker': '159650',
#      'suggest': {'input': ['하', '이골드', '8', '호'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'NF7MRnYByPpEVaaDAbqS',
#     '_score': 1.0,
#     '_source': {'name': '하이스틸',
#      'ticker': '071090',
#      'suggest': {'input': ['하이', '스틸'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'NV7MRnYByPpEVaaDAbqf',
#     '_score': 1.0,
#     '_source': {'name': '하이트론',
#      'ticker': '019490',
#      'suggest': {'input': ['하이', '트론'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Nl7MRnYByPpEVaaDAbqs',
#     '_score': 1.0,
#     '_source': {'name': '하이트진로',
#      'ticker': '000080',
#      'suggest': {'input': ['하이트진로'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'N17MRnYByPpEVaaDAbq4',
#     '_score': 1.0,
#     '_source': {'name': '하이트진로홀딩스',
#      'ticker': '000140',
#      'suggest': {'input': ['하이트진로', '홀딩스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'OF7MRnYByPpEVaaDAbrF',
#     '_score': 1.0,
#     '_source': {'name': '한국ANKOR유전',
#      'ticker': '152550',
#      'suggest': {'input': ['한국', 'ANKOR', '유전'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'OV7MRnYByPpEVaaDAbrR',
#     '_score': 1.0,
#     '_source': {'name': '한국가스공사',
#      'ticker': '036460',
#      'suggest': {'input': ['한국가스공사'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Ol7MRnYByPpEVaaDAbre',
#     '_score': 1.0,
#     '_source': {'name': '한국공항',
#      'ticker': '005430',
#      'suggest': {'input': ['한국', '공항'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'O17MRnYByPpEVaaDAbrr',
#     '_score': 1.0,
#     '_source': {'name': '한국금융지주',
#      'ticker': '071050',
#      'suggest': {'input': ['한국', '금융', '지주'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'PF7MRnYByPpEVaaDAbr3',
#     '_score': 1.0,
#     '_source': {'name': '한국내화',
#      'ticker': '010040',
#      'suggest': {'input': ['한국', '내화'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'PV7MRnYByPpEVaaDAroF',
#     '_score': 1.0,
#     '_source': {'name': '한국단자',
#      'ticker': '025540',
#      'suggest': {'input': ['한국', '단자'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Pl7MRnYByPpEVaaDAroS',
#     '_score': 1.0,
#     '_source': {'name': '한국석유',
#      'ticker': '004090',
#      'suggest': {'input': ['한국', '석유'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'P17MRnYByPpEVaaDArof',
#     '_score': 1.0,
#     '_source': {'name': '한국쉘석유',
#      'ticker': '002960',
#      'suggest': {'input': ['한국쉘석유'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'QF7MRnYByPpEVaaDAror',
#     '_score': 1.0,
#     '_source': {'name': '한국자산신탁',
#      'ticker': '123890',
#      'suggest': {'input': ['한국', '자산', '신탁'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'QV7MRnYByPpEVaaDAro4',
#     '_score': 1.0,
#     '_source': {'name': '한국전력',
#      'ticker': '015760',
#      'suggest': {'input': ['한국전력'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Ql7MRnYByPpEVaaDArpF',
#     '_score': 1.0,
#     '_source': {'name': '한국전자홀딩스',
#      'ticker': '006200',
#      'suggest': {'input': ['한국', '전자', '홀딩스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Q17MRnYByPpEVaaDArpS',
#     '_score': 1.0,
#     '_source': {'name': '한국제지',
#      'ticker': '002300',
#      'suggest': {'input': ['한국', '제지'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'RF7MRnYByPpEVaaDArpf',
#     '_score': 1.0,
#     '_source': {'name': '한국종합기술',
#      'ticker': '023350',
#      'suggest': {'input': ['한국', '종합', '기술'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'RV7MRnYByPpEVaaDArpy',
#     '_score': 1.0,
#     '_source': {'name': '한국주강',
#      'ticker': '025890',
#      'suggest': {'input': ['한국', '주강'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Rl7MRnYByPpEVaaDArp_',
#     '_score': 1.0,
#     '_source': {'name': '한국주철관',
#      'ticker': '000970',
#      'suggest': {'input': ['한국', '주철관'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'R17MRnYByPpEVaaDArqM',
#     '_score': 1.0,
#     '_source': {'name': '한국철강',
#      'ticker': '104700',
#      'suggest': {'input': ['한국', '철강'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'SF7MRnYByPpEVaaDArqY',
#     '_score': 1.0,
#     '_source': {'name': '한국카본',
#      'ticker': '017960',
#      'suggest': {'input': ['한국', '카본'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'SV7MRnYByPpEVaaDArql',
#     '_score': 1.0,
#     '_source': {'name': '한국콜마',
#      'ticker': '161890',
#      'suggest': {'input': ['한국', '콜', '마'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Sl7MRnYByPpEVaaDArq4',
#     '_score': 1.0,
#     '_source': {'name': '한국콜마홀딩스',
#      'ticker': '024720',
#      'suggest': {'input': ['한국', '콜', '마', '홀딩스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'S17MRnYByPpEVaaDArrF',
#     '_score': 1.0,
#     '_source': {'name': '한국타이어앤테크놀로지',
#      'ticker': '161390',
#      'suggest': {'input': ['한국', '타이어', '앤', '테크놀로지'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'TF7MRnYByPpEVaaDArrT',
#     '_score': 1.0,
#     '_source': {'name': '한국테크놀로지그룹',
#      'ticker': '000240',
#      'suggest': {'input': ['한국', '테크놀로지', '그룹'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'TV7MRnYByPpEVaaDArrg',
#     '_score': 1.0,
#     '_source': {'name': '한국토지신탁',
#      'ticker': '034830',
#      'suggest': {'input': ['한국', '토지', '신탁'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Tl7MRnYByPpEVaaDArru',
#     '_score': 1.0,
#     '_source': {'name': '한국특수형강',
#      'ticker': '007280',
#      'suggest': {'input': ['한국', '특수', '형강'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'T17MRnYByPpEVaaDArr6',
#     '_score': 1.0,
#     '_source': {'name': '한국패러랠',
#      'ticker': '168490',
#      'suggest': {'input': ['한국', '패러', '랠'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'UF7MRnYByPpEVaaDA7oI',
#     '_score': 1.0,
#     '_source': {'name': '한국프랜지',
#      'ticker': '010100',
#      'suggest': {'input': ['한국', '프랜', '지'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'UV7MRnYByPpEVaaDA7oV',
#     '_score': 1.0,
#     '_source': {'name': '한국항공우주',
#      'ticker': '047810',
#      'suggest': {'input': ['한국', '항공우주'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Ul7MRnYByPpEVaaDA7oi',
#     '_score': 1.0,
#     '_source': {'name': '한국화장품',
#      'ticker': '123690',
#      'suggest': {'input': ['한국', '화장품'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'U17MRnYByPpEVaaDA7ov',
#     '_score': 1.0,
#     '_source': {'name': '한국화장품제조',
#      'ticker': '003350',
#      'suggest': {'input': ['한국', '화장품', '제조'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'VF7MRnYByPpEVaaDA7o9',
#     '_score': 1.0,
#     '_source': {'name': '한농화성',
#      'ticker': '011500',
#      'suggest': {'input': ['한', '농화', '성'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'VV7MRnYByPpEVaaDA7pV',
#     '_score': 1.0,
#     '_source': {'name': '한독',
#      'ticker': '002390',
#      'suggest': {'input': ['한독'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Vl7MRnYByPpEVaaDA7pj',
#     '_score': 1.0,
#     '_source': {'name': '한라',
#      'ticker': '014790',
#      'suggest': {'input': ['한라'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'V17MRnYByPpEVaaDA7pv',
#     '_score': 1.0,
#     '_source': {'name': '한라홀딩스',
#      'ticker': '060980',
#      'suggest': {'input': ['한라', '홀딩스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'WF7MRnYByPpEVaaDA7p9',
#     '_score': 1.0,
#     '_source': {'name': '한미글로벌',
#      'ticker': '053690',
#      'suggest': {'input': ['한미', '글로벌'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'WV7MRnYByPpEVaaDA7qK',
#     '_score': 1.0,
#     '_source': {'name': '한미반도체',
#      'ticker': '042700',
#      'suggest': {'input': ['한미', '반도체'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Wl7MRnYByPpEVaaDA7qY',
#     '_score': 1.0,
#     '_source': {'name': '한미사이언스',
#      'ticker': '008930',
#      'suggest': {'input': ['한미', '사이언스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'W17MRnYByPpEVaaDA7qk',
#     '_score': 1.0,
#     '_source': {'name': '한미약품',
#      'ticker': '128940',
#      'suggest': {'input': ['한미', '약품'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'XF7MRnYByPpEVaaDA7q2',
#     '_score': 1.0,
#     '_source': {'name': '한샘',
#      'ticker': '009240',
#      'suggest': {'input': ['한샘'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'XV7MRnYByPpEVaaDA7rD',
#     '_score': 1.0,
#     '_source': {'name': '한섬',
#      'ticker': '020000',
#      'suggest': {'input': ['한섬'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Xl7MRnYByPpEVaaDA7rR',
#     '_score': 1.0,
#     '_source': {'name': '한성기업',
#      'ticker': '003680',
#      'suggest': {'input': ['한성', '기업'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'X17MRnYByPpEVaaDA7rd',
#     '_score': 1.0,
#     '_source': {'name': '한세실업',
#      'ticker': '105630',
#      'suggest': {'input': ['한', '세', '실업'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'YF7MRnYByPpEVaaDA7rr',
#     '_score': 1.0,
#     '_source': {'name': '한세엠케이',
#      'ticker': '069640',
#      'suggest': {'input': ['한세', '엠케이'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'YV7MRnYByPpEVaaDA7r3',
#     '_score': 1.0,
#     '_source': {'name': '한세예스24홀딩스',
#      'ticker': '016450',
#      'suggest': {'input': ['한', '세예', '스', '24', '홀딩스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Yl7MRnYByPpEVaaDBLoF',
#     '_score': 1.0,
#     '_source': {'name': '한솔PNS',
#      'ticker': '010420',
#      'suggest': {'input': ['한솔', 'PNS'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Y17MRnYByPpEVaaDBLoR',
#     '_score': 1.0,
#     '_source': {'name': '한솔로지스틱스',
#      'ticker': '009180',
#      'suggest': {'input': ['한솔', '로지', '스틱스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'ZF7MRnYByPpEVaaDBLof',
#     '_score': 1.0,
#     '_source': {'name': '한솔제지',
#      'ticker': '213500',
#      'suggest': {'input': ['한솔제지'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'ZV7MRnYByPpEVaaDBLot',
#     '_score': 1.0,
#     '_source': {'name': '한솔케미칼',
#      'ticker': '014680',
#      'suggest': {'input': ['한솔케미칼'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Zl7MRnYByPpEVaaDBLo5',
#     '_score': 1.0,
#     '_source': {'name': '한솔테크닉스',
#      'ticker': '004710',
#      'suggest': {'input': ['한솔', '테크', '닉스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'Z17MRnYByPpEVaaDBLpG',
#     '_score': 1.0,
#     '_source': {'name': '한솔홀딩스',
#      'ticker': '004150',
#      'suggest': {'input': ['한솔', '홀딩스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'aF7MRnYByPpEVaaDBLpT',
#     '_score': 1.0,
#     '_source': {'name': '한솔홈데코',
#      'ticker': '025750',
#      'suggest': {'input': ['한솔', '홈', '데코'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'aV7MRnYByPpEVaaDBLpg',
#     '_score': 1.0,
#     '_source': {'name': '한신공영',
#      'ticker': '004960',
#      'suggest': {'input': ['한신공영'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'al7MRnYByPpEVaaDBLpt',
#     '_score': 1.0,
#     '_source': {'name': '한신기계',
#      'ticker': '011700',
#      'suggest': {'input': ['한신', '기계'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'a17MRnYByPpEVaaDBLp6',
#     '_score': 1.0,
#     '_source': {'name': '한양증권',
#      'ticker': '001750',
#      'suggest': {'input': ['한양', '증권'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'bF7MRnYByPpEVaaDBLqI',
#     '_score': 1.0,
#     '_source': {'name': '한온시스템',
#      'ticker': '018880',
#      'suggest': {'input': ['한온', '시스템'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'bV7MRnYByPpEVaaDBLqW',
#     '_score': 1.0,
#     '_source': {'name': '한올바이오파마',
#      'ticker': '009420',
#      'suggest': {'input': ['한올', '바이오', '파마'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'bl7MRnYByPpEVaaDBLqj',
#     '_score': 1.0,
#     '_source': {'name': '한익스프레스',
#      'ticker': '014130',
#      'suggest': {'input': ['한', '익스프레스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'b17MRnYByPpEVaaDBLqw',
#     '_score': 1.0,
#     '_source': {'name': '한일시멘트',
#      'ticker': '300720',
#      'suggest': {'input': ['한', '일', '시멘트'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'cF7MRnYByPpEVaaDBLrD',
#     '_score': 1.0,
#     '_source': {'name': '한일철강',
#      'ticker': '002220',
#      'suggest': {'input': ['한', '일', '철강'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'cV7MRnYByPpEVaaDBLrX',
#     '_score': 1.0,
#     '_source': {'name': '한일현대시멘트',
#      'ticker': '006390',
#      'suggest': {'input': ['한', '일', '현대', '시멘트'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'cl7MRnYByPpEVaaDBLrk',
#     '_score': 1.0,
#     '_source': {'name': '한일홀딩스',
#      'ticker': '003300',
#      'suggest': {'input': ['한', '일', '홀딩스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'c17MRnYByPpEVaaDBLry',
#     '_score': 1.0,
#     '_source': {'name': '한전KPS',
#      'ticker': '051600',
#      'suggest': {'input': ['한전', 'KPS'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'dF7MRnYByPpEVaaDBLr_',
#     '_score': 1.0,
#     '_source': {'name': '한전기술',
#      'ticker': '052690',
#      'suggest': {'input': ['한전', '기술'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'v17LRnYByPpEVaaD7bg8',
#     '_score': 1.0,
#     '_source': {'name': '만호제강',
#      'ticker': '001080',
#      'suggest': {'input': ['만호', '제강'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'wF7LRnYByPpEVaaD7bhM',
#     '_score': 1.0,
#     '_source': {'name': '맥쿼리인프라',
#      'ticker': '088980',
#      'suggest': {'input': ['맥쿼리', '인프라'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'wV7LRnYByPpEVaaD7bhZ',
#     '_score': 1.0,
#     '_source': {'name': '맵스리얼티1',
#      'ticker': '094800',
#      'suggest': {'input': ['맵', '스리', '얼', '티', '1'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'wl7LRnYByPpEVaaD7bhl',
#     '_score': 1.0,
#     '_source': {'name': '쎌마테라퓨틱스',
#      'ticker': '015540',
# ...
#     '_score': 1.0,
#     '_source': {'name': '웰바이오텍',
#      'ticker': '010600',
#      'suggest': {'input': ['웰', '바이오', '텍'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'ml7LRnYByPpEVaaD-blD',
#     '_score': 1.0,
#     '_source': {'name': '윌비스',
#      'ticker': '008600',
#      'suggest': {'input': ['윌', '비스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'm17LRnYByPpEVaaD-blP',
#     '_score': 1.0,
#     '_source': {'name': '유나이티드제약',
#      'ticker': '033270',
#      'suggest': {'input': ['유나이티', '드', '제약'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'nF7LRnYByPpEVaaD-blb',
#     '_score': 1.0,
#     '_source': {'name': '유니드',
#      'ticker': '014830',
#      'suggest': {'input': ['유니', '드'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'nV7LRnYByPpEVaaD-bln',
#     '_score': 1.0,
#     '_source': {'name': '유니온',
#      'ticker': '000910',
#      'suggest': {'input': ['유니온'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'nl7LRnYByPpEVaaD-bl0',
#     '_score': 1.0,
#     '_source': {'name': '유니온머티리얼',
#      'ticker': '047400',
#      'suggest': {'input': ['유니온', '머티', '리얼'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'n17LRnYByPpEVaaD-bmA',
#     '_score': 1.0,
#     '_source': {'name': '유니켐',
#      'ticker': '011330',
#      'suggest': {'input': ['유니', '켐'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'oF7LRnYByPpEVaaD-bmN',
#     '_score': 1.0,
#     '_source': {'name': '유니퀘스트',
#      'ticker': '077500',
#      'suggest': {'input': ['유니', '퀘스트'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'oV7LRnYByPpEVaaD-bmb',
#     '_score': 1.0,
#     '_source': {'name': '유성기업',
#      'ticker': '002920',
#      'suggest': {'input': ['유성기업'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'ol7LRnYByPpEVaaD-bmt',
#     '_score': 1.0,
#     '_source': {'name': '유수홀딩스',
#      'ticker': '000700',
#      'suggest': {'input': ['유수', '홀딩스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'o17LRnYByPpEVaaD-bm7',
#     '_score': 1.0,
#     '_source': {'name': '유안타증권',
#      'ticker': '003470',
#      'suggest': {'input': ['유안', '타', '증권'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'pF7LRnYByPpEVaaD-bnH',
#     '_score': 1.0,
#     '_source': {'name': '유양디앤유',
#      'ticker': '011690',
#      'suggest': {'input': ['유양', '디', '앤', '유'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'pV7LRnYByPpEVaaD-bnV',
#     '_score': 1.0,
#     '_source': {'name': '유엔젤',
#      'ticker': '072130',
#      'suggest': {'input': ['유엔', '젤'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'pl7LRnYByPpEVaaD-bnh',
#     '_score': 1.0,
#     '_source': {'name': '유유제약',
#      'ticker': '000220',
#      'suggest': {'input': ['유유', '제약'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'p17LRnYByPpEVaaD-bnv',
#     '_score': 1.0,
#     '_source': {'name': '유진투자증권',
#      'ticker': '001200',
#      'suggest': {'input': ['유진', '투자', '증권'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'qF7LRnYByPpEVaaD-bn8',
#     '_score': 1.0,
#     '_source': {'name': '유한양행',
#      'ticker': '000100',
#      'suggest': {'input': ['유한양행'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'qV7LRnYByPpEVaaD-rkK',
#     '_score': 1.0,
#     '_source': {'name': '유화증권',
#      'ticker': '003460',
#      'suggest': {'input': ['유화', '증권'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'ql7LRnYByPpEVaaD-rkW',
#     '_score': 1.0,
#     '_source': {'name': '율촌화학',
#      'ticker': '008730',
#      'suggest': {'input': ['율촌', '화학'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'q17LRnYByPpEVaaD-rkk',
#     '_score': 1.0,
#     '_source': {'name': '이건산업',
#      'ticker': '008250',
#      'suggest': {'input': ['이건', '산업'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'rF7LRnYByPpEVaaD-rkx',
#     '_score': 1.0,
#     '_source': {'name': '이구산업',
#      'ticker': '025820',
#      'suggest': {'input': ['이구', '산업'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'rV7LRnYByPpEVaaD-rk_',
#     '_score': 1.0,
#     '_source': {'name': '이노션',
#      'ticker': '214320',
#      'suggest': {'input': ['이노션'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'rl7LRnYByPpEVaaD-rlL',
#     '_score': 1.0,
#     '_source': {'name': '이리츠코크렙',
#      'ticker': '088260',
#      'suggest': {'input': ['이', '리츠', '코크', '렙'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'r17LRnYByPpEVaaD-rlZ',
#     '_score': 1.0,
#     '_source': {'name': '이마트',
#      'ticker': '139480',
#      'suggest': {'input': ['이마트'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'sF7LRnYByPpEVaaD-rlm',
#     '_score': 1.0,
#     '_source': {'name': '이수페타시스',
#      'ticker': '007660',
#      'suggest': {'input': ['이수', '페타', '시스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'sV7LRnYByPpEVaaD-rl5',
#     '_score': 1.0,
#     '_source': {'name': '이수화학',
#      'ticker': '005950',
#      'suggest': {'input': ['이수화학'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'sl7LRnYByPpEVaaD-rmL',
#     '_score': 1.0,
#     '_source': {'name': '이스타코',
#      'ticker': '015020',
#      'suggest': {'input': ['이', '스타', '코'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 's17LRnYByPpEVaaD-rma',
#     '_score': 1.0,
#     '_source': {'name': '이아이디',
#      'ticker': '093230',
#      'suggest': {'input': ['이', '아이디'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'tF7LRnYByPpEVaaD-rmn',
#     '_score': 1.0,
#     '_source': {'name': '이연제약',
#      'ticker': '102460',
#      'suggest': {'input': ['이연제', '약'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'tV7LRnYByPpEVaaD-rm2',
#     '_score': 1.0,
#     '_source': {'name': '이월드',
#      'ticker': '084680',
#      'suggest': {'input': ['이월드'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'tl7LRnYByPpEVaaD-rnD',
#     '_score': 1.0,
#     '_source': {'name': '이화산업',
#      'ticker': '000760',
#      'suggest': {'input': ['이', '화', '산업'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 't17LRnYByPpEVaaD-rnX',
#     '_score': 1.0,
#     '_source': {'name': '인디에프',
#      'ticker': '014990',
#      'suggest': {'input': ['인디', '에프'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'uF7LRnYByPpEVaaD-rnk',
#     '_score': 1.0,
#     '_source': {'name': '인스코비',
#      'ticker': '006490',
#      'suggest': {'input': ['인스', '코비'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'uV7LRnYByPpEVaaD-rny',
#     '_score': 1.0,
#     '_source': {'name': '인지컨트롤스',
#      'ticker': '023800',
#      'suggest': {'input': ['인지', '컨트롤', '스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'ul7LRnYByPpEVaaD-rn_',
#     '_score': 1.0,
#     '_source': {'name': '인천도시가스',
#      'ticker': '034590',
#      'suggest': {'input': ['인천', '도시', '가스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'u17LRnYByPpEVaaD-7kM',
#     '_score': 1.0,
#     '_source': {'name': '인터지스',
#      'ticker': '129260',
#      'suggest': {'input': ['인터', '지스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'vF7LRnYByPpEVaaD-7kZ',
#     '_score': 1.0,
#     '_source': {'name': '인팩',
#      'ticker': '023810',
#      'suggest': {'input': ['인', '팩'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'vV7LRnYByPpEVaaD-7kl',
#     '_score': 1.0,
#     '_source': {'name': '일동제약',
#      'ticker': '249420',
#      'suggest': {'input': ['일동', '제약'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'vl7LRnYByPpEVaaD-7ky',
#     '_score': 1.0,
#     '_source': {'name': '일동홀딩스',
#      'ticker': '000230',
#      'suggest': {'input': ['일동', '홀딩스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'v17LRnYByPpEVaaD-7k-',
#     '_score': 1.0,
#     '_source': {'name': '일성건설',
#      'ticker': '013360',
#      'suggest': {'input': ['일성건설'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'wF7LRnYByPpEVaaD-7lL',
#     '_score': 1.0,
#     '_source': {'name': '일성신약',
#      'ticker': '003120',
#      'suggest': {'input': ['일', '성', '신약'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'wV7LRnYByPpEVaaD-7lY',
#     '_score': 1.0,
#     '_source': {'name': '일신방직',
#      'ticker': '003200',
#      'suggest': {'input': ['일신', '방직'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'wl7LRnYByPpEVaaD-7ll',
#     '_score': 1.0,
#     '_source': {'name': '일신석재',
#      'ticker': '007110',
#      'suggest': {'input': ['일신', '석재'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'w17LRnYByPpEVaaD-7lx',
#     '_score': 1.0,
#     '_source': {'name': '일양약품',
#      'ticker': '007570',
#      'suggest': {'input': ['일양', '약품'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'xF7LRnYByPpEVaaD-7l_',
#     '_score': 1.0,
#     '_source': {'name': '일정실업',
#      'ticker': '008500',
#      'suggest': {'input': ['일정', '실업'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'xV7LRnYByPpEVaaD-7mL',
#     '_score': 1.0,
#     '_source': {'name': '일진다이아',
#      'ticker': '081000',
#      'suggest': {'input': ['일진', '다이아'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'xl7LRnYByPpEVaaD-7mY',
#     '_score': 1.0,
#     '_source': {'name': '일진디스플',
#      'ticker': '020760',
#      'suggest': {'input': ['일진', '디스', '플'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'x17LRnYByPpEVaaD-7ml',
#     '_score': 1.0,
#     '_source': {'name': '일진머티리얼즈',
#      'ticker': '020150',
#      'suggest': {'input': ['일진', '머티', '리얼', '즈'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'yF7LRnYByPpEVaaD-7my',
#     '_score': 1.0,
#     '_source': {'name': '일진전기',
#      'ticker': '103590',
#      'suggest': {'input': ['일진', '전기'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'yV7LRnYByPpEVaaD-7m_',
#     '_score': 1.0,
#     '_source': {'name': '일진홀딩스',
#      'ticker': '015860',
#      'suggest': {'input': ['일진', '홀딩스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'yl7LRnYByPpEVaaD-7nM',
#     '_score': 1.0,
#     '_source': {'name': '잇츠한불',
#      'ticker': '226320',
#      'suggest': {'input': ['잇츠', '한불'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'y17LRnYByPpEVaaD-7nZ',
#     '_score': 1.0,
#     '_source': {'name': '자화전자',
#      'ticker': '033240',
#      'suggest': {'input': ['자화', '전자'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'zF7LRnYByPpEVaaD-7nl',
#     '_score': 1.0,
#     '_source': {'name': '전방',
#      'ticker': '000950',
#      'suggest': {'input': ['전방'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'zV7LRnYByPpEVaaD-7ny',
#     '_score': 1.0,
#     '_source': {'name': '제이에스코퍼레이션',
#      'ticker': '194370',
#      'suggest': {'input': ['제이', '에스', '코퍼레이션'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'zl7LRnYByPpEVaaD-7n_',
#     '_score': 1.0,
#     '_source': {'name': '제이준코스메틱',
#      'ticker': '025620',
#      'suggest': {'input': ['제이준', '코', '스메', '틱'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'z17LRnYByPpEVaaD_LkL',
#     '_score': 1.0,
#     '_source': {'name': '제일기획',
#      'ticker': '030000',
#      'suggest': {'input': ['제일기획'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '0F7LRnYByPpEVaaD_LkZ',
#     '_score': 1.0,
#     '_source': {'name': '제일약품',
#      'ticker': '271980',
#      'suggest': {'input': ['제일', '약품'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '0V7LRnYByPpEVaaD_Lkn',
#     '_score': 1.0,
#     '_source': {'name': '제일연마',
#      'ticker': '001560',
#      'suggest': {'input': ['제일', '연마'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '0l7LRnYByPpEVaaD_Lk0',
#     '_score': 1.0,
#     '_source': {'name': '제일파마홀딩스',
#      'ticker': '002620',
#      'suggest': {'input': ['제일', '파마', '홀딩스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '017LRnYByPpEVaaD_LlB',
#     '_score': 1.0,
#     '_source': {'name': '제주은행',
#      'ticker': '006220',
#      'suggest': {'input': ['제주', '은행'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '1F7LRnYByPpEVaaD_LlP',
#     '_score': 1.0,
#     '_source': {'name': '제주항공',
#      'ticker': '089590',
#      'suggest': {'input': ['제주', '항공'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '1V7LRnYByPpEVaaD_Llc',
#     '_score': 1.0,
#     '_source': {'name': '조광페인트',
#      'ticker': '004910',
#      'suggest': {'input': ['조광페인트'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '1l7LRnYByPpEVaaD_Llp',
#     '_score': 1.0,
#     '_source': {'name': '조광피혁',
#      'ticker': '004700',
#      'suggest': {'input': ['조광', '피혁'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '117LRnYByPpEVaaD_Ll2',
#     '_score': 1.0,
#     '_source': {'name': '조비',
#      'ticker': '001550',
#      'suggest': {'input': ['조비'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '2F7LRnYByPpEVaaD_LmE',
#     '_score': 1.0,
#     '_source': {'name': '조선내화',
#      'ticker': '000480',
#      'suggest': {'input': ['조선내화'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '2V7LRnYByPpEVaaD_LmS',
#     '_score': 1.0,
#     '_source': {'name': '조선선재',
#      'ticker': '120030',
#      'suggest': {'input': ['조선', '선재'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '2l7LRnYByPpEVaaD_Lme',
#     '_score': 1.0,
#     '_source': {'name': '조일알미늄',
#      'ticker': '018470',
#      'suggest': {'input': ['조일', '알미늄'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '217LRnYByPpEVaaD_Lmr',
#     '_score': 1.0,
#     '_source': {'name': '조흥',
#      'ticker': '002600',
#      'suggest': {'input': ['조흥'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '3F7LRnYByPpEVaaD_Lm4',
#     '_score': 1.0,
#     '_source': {'name': '종근당',
#      'ticker': '185750',
#      'suggest': {'input': ['종근당'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '3V7LRnYByPpEVaaD_LnF',
#     '_score': 1.0,
#     '_source': {'name': '종근당바이오',
#      'ticker': '063160',
#      'suggest': {'input': ['종근당', '바이오'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '3l7LRnYByPpEVaaD_LnS',
#     '_score': 1.0,
#     '_source': {'name': '종근당홀딩스',
#      'ticker': '001630',
#      'suggest': {'input': ['종근당', '홀딩스'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '317LRnYByPpEVaaD_Lnf',
#     '_score': 1.0,
#     '_source': {'name': '주연테크',
#      'ticker': '044380',
#      'suggest': {'input': ['주연', '테크'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '4F7LRnYByPpEVaaD_Lns',
#     '_score': 1.0,
#     '_source': {'name': '지엠비코리아',
#      'ticker': '013870',
#      'suggest': {'input': ['지', '엠', '비', '코리아'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '4V7LRnYByPpEVaaD_Ln_',
#     '_score': 1.0,
#     '_source': {'name': '지역난방공사',
#      'ticker': '071320',
#      'suggest': {'input': ['지역난방', '공사'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': '4l7LRnYByPpEVaaD_bkM',
#     '_score': 1.0,
#     '_source': {'name': '지코',
#      'ticker': '010580',
#      'suggest': {'input': ['지코'], 'weight': 1}}},
#    {'_index': 'tickers',
#     '_type': '_doc',
#     '_id': 'ul7MRnYByPpEVaaDCboF',
#     '_score': 1.0,
#     '_source': {'name': '흥아해운',
#      'ticker': '003280',
#      'suggest': {'input': ['흥아', '해운'], 'weight': 1}}}]}}

# %% [markdown]
# ## Prefix Query
#
# 앞글자가 똑같아야 합니다. 예를 들어 "하이닉스" 로는 검색이 안됩니다.

# %%
query = {
    'query': {
        'prefix': {
            'name': {
                'value': 'ㅎ'
            }
        }
    }
}
es.search(index='tickers', body=query)
# Out:
# {'took': 1,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 0, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []}}

# %% [markdown]
# ## Edge N-gram

# %%
ret = es.indices.analyze({'tokenizer': 'edge_ngram',
                          'text': ['SK', '하이닉스']})

[i['token'] for i in ret['tokens']]
# Out:
# ['S', 'SK', '하', '하이']

# %% [markdown]
# ## Suggest

# %%
query = {
    "suggest": {
        "stock-suggest": {
            'prefix': '에',
            'completion': {
                'field': 'suggest'
            }}}}

es.search(index='tickers', body=query)
# Out:
# {'took': 2,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 0, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'suggest': {'stock-suggest': [{'text': '에',
#     'offset': 0,
#     'length': 1,
#     'options': [{'text': '에',
#       '_index': 'tickers',
#       '_type': '_doc',
#       '_id': 'Gl7MRnYByPpEVaaDALon',
#       '_score': 1.0,
#       '_source': {'name': '티에이치엔',
#        'ticker': '019180',
#        'suggest': {'input': ['티', '에', '이치엔'], 'weight': 1}}},
#      {'text': '에',
#       '_index': 'tickers',
#       '_type': '_doc',
#       '_id': 'cV7LRnYByPpEVaaD97kF',
#       '_score': 1.0,
#       '_source': {'name': '에쓰씨엔지니어링',
#        'ticker': '023960',
#        'suggest': {'input': ['에', '쓰', '씨', '엔지니어링'], 'weight': 1}}},
#      {'text': '에',
#       '_index': 'tickers',
#       '_type': '_doc',
#       '_id': 'dl7LRnYByPpEVaaD97lI',
#       '_score': 1.0,
#       '_source': {'name': '에이프로젠 KIC',
#        'ticker': '007460',
#        'suggest': {'input': ['에', '이프로', '젠', 'KIC'], 'weight': 1}}},
#      {'text': '에',
#       '_index': 'tickers',
#       '_type': '_doc',
#       '_id': 'd17LRnYByPpEVaaD97lW',
#       '_score': 1.0,
#       '_source': {'name': '에이프로젠제약',
#        'ticker': '003060',
#        'suggest': {'input': ['에', '이프로', '젠', '제약'], 'weight': 1}}},
#      {'text': '에',
#       '_index': 'tickers',
#       '_type': '_doc',
#       '_id': '0l7LRnYByPpEVaaD7rg-',
#       '_score': 1.0,
#       '_source': {'name': '미래에셋대우',
#        'ticker': '006800',
#        'suggest': {'input': ['미래', '에', '셋', '대우'], 'weight': 1}}}]}]}}
